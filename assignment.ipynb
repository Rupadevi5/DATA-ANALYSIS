# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
b=pd.read_csv("/content/temp.csv")
print(b)

avg_temp=b['temperature'].mean()
high_temp=b['temperature'].max()
low_temp=b['temperature'].min()
threshold=30
days_above_threshold=b[b['temperature']>threshold].shape[0]

print("Average temperature:",avg_temp)
print("Highest temperature:",high_temp)
print("Lowest temperature:",low_temp)
print("Number of days temperature exceeded",threshold,"degree celsius:",days_above_threshold)

b.plot(kind='line',color='red')
plt.title("Temperature for july month")
plt.xlabel("Days")
plt.ylabel("Temperature")
# Out:
#      month  temperature
# 0   01-Jul           25
# 1   02-Jul           10
# 2   03-Jul            0
# 3   04-Jul          -10
# 4   05-Jul           35
# 5   06-Jul           40
# 6   07-Jul           15
# 7   08-Jul            5
# 8   09-Jul           -5
# 9   10-Jul           30
# 10  11-Jul           20
# 11  12-Jul           12
# 12  13-Jul          -15
# 13  14-Jul           18
# 14  15-Jul           22
# 15  16-Jul            8
# 16  17-Jul           -2
# 17  18-Jul           32
# 18  19-Jul           27
# 19  20-Jul            3
# 20  21-Jul           -8
# 21  22-Jul           38
# 22  23-Jul           17
# 23  24-Jul            7
# 24  25-Jul          -12
# 25  26-Jul           23
# 26  27-Jul           13
# 27  28-Jul            2
# 28  29-Jul          -20
# 29  30-Jul           33
# 30  31-Jul           28
# Average temperature: 12.612903225806452
# Highest temperature: 40
# Lowest temperature: -20
# Number of days temperature exceeded 30 degree celsius: 5
# Text(0, 0.5, 'Temperature')
